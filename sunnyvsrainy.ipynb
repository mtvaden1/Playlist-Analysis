# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util

import requests
import pandas as pd
import numpy as np
import json
import os
import dotenv
import sys
import tekore as tk
sys.tracebacklimit = 0 # turn off the error tracebacks

from colorthief import ColorThief
from urllib.request import urlopen
import io

# %%
dotenv.load_dotenv()


username = 'michael_vaden'

spot_id = os.getenv('spot_id')
spot_secret = os.getenv('spot_secret')
redirect_uri= 'https://www.virginia.edu/'


client_credentials_manager = SpotifyClientCredentials(client_id=spot_id, client_secret=spot_secret)


scope = "playlist-modify-public playlist-modify-private playlist-read-private playlist-read-collaborative user-library-modify"

token = util.prompt_for_user_token(username, scope, spot_id, spot_secret, redirect_uri, show_dialog=True)

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager, auth=token)

# %%
def get_tracks(user, playlist):
    myjson = sp.user_playlist_tracks(user, playlist)

    tracks = myjson['items']

    while myjson['next']:
        myjson = sp.next(myjson)
        tracks.extend(myjson['items'])

    return pd.json_normalize(tracks)

# %%
def get_tracks_from_url(username, url):
    playlist_URI = url.split("/")[-1].split("?")[0]

    return get_tracks(username, playlist_URI)

# %%
def add_song_features(df):
    song_features = pd.DataFrame()
    for track in df['track.uri']:
        song_features = pd.concat([song_features, pd.json_normalize(sp.audio_features(track))])

    return df.merge(song_features, left_on='track.uri', right_on='uri')

# %%
rainy1 = get_tracks_from_url('spotify', "https://open.spotify.com/playlist/37i9dQZF1DXbvABJXBIyiY?si=e2da83ce834b40c5") # rainy day
rainy2 = get_tracks_from_url('Circles Records', "https://open.spotify.com/playlist/3r82Jvzw3SSGKKiKf3dXMM?si=01242f93e6524a23").loc[:210,] # rainy days music
rainy3 = get_tracks_from_url('tiarafernando', "https://open.spotify.com/playlist/47S4MBG0EEXwA0GdJUA4Ur?si=0e19386208f944c3") # a playlist for rainy days

# %%
sunny1 = get_tracks_from_url('spotify', "https://open.spotify.com/playlist/37i9dQZF1DX1BzILRveYHb?si=ac80c28e8a104400") # sunny day
sunny2 = get_tracks_from_url('spotify', "https://open.spotify.com/playlist/37i9dQZF1DXd1MXcE8WTXq?si=8662accbcb644c0e") # summer throwbacks
sunny3 = get_tracks_from_url('spotify', "https://open.spotify.com/playlist/37i9dQZF1DX5Ozry5U6G0d?si=953f1b53a9584ce7") # summer party
sunny4 = get_tracks_from_url('spotify', 'https://open.spotify.com/playlist/37i9dQZF1DX9fZ7amiNVu6?si=bf527d1910ff4453') # feel good summer

# %%
rainy = pd.concat([rainy1, rainy2, rainy3]).drop_duplicates('track.uri')
#rainy

# %%
sunny = pd.concat([sunny1, sunny2, sunny3, sunny4]).drop_duplicates('track.uri')
#sunny

# %%
#rainy.describe()
rainy = rainy[['track.uri', 'track.id', 'track.name', 'track.popularity']].dropna()

# %%
#sunny.describe()
sunny = sunny[['track.uri', 'track.id', 'track.name', 'track.popularity']].dropna()

# %%
sunny_features = add_song_features(sunny).drop(['id', 'uri', 'track_href', 'analysis_url', 'type'], axis=1)
rainy_features = add_song_features(rainy).drop(['id', 'uri', 'track_href', 'analysis_url', 'type'], axis=1)

# %%
sunny_features['weather_type'] = 'sun'
rainy_features['weather_type'] = 'rain'
weather_songs = pd.concat([sunny_features, rainy_features])
weather_songs
# Out:
#                                 track.uri                track.id  \
# 0    spotify:track:3ZpQiJ78LKINrW9SQTgbXd  3ZpQiJ78LKINrW9SQTgbXd
# 1    spotify:track:3XKIUb7HzIF1Vu9usunMzc  3XKIUb7HzIF1Vu9usunMzc
# 2    spotify:track:0ofHAoxe9vBkTCp2UQIavz  0ofHAoxe9vBkTCp2UQIavz
# 3    spotify:track:0bRXwKfigvpKZUurwqAlEh  0bRXwKfigvpKZUurwqAlEh
# 4    spotify:track:1YLJVmuzeM2YSUkCCaTNUB  1YLJVmuzeM2YSUkCCaTNUB
# ..                                    ...                     ...
# 386  spotify:track:39sDitIeCMrVX2QyXHY46t  39sDitIeCMrVX2QyXHY46t
# 387  spotify:track:3Q4zjvPKaxkGUo0MTdrbir  3Q4zjvPKaxkGUo0MTdrbir
# 388  spotify:track:1MHb9ROmrgyGvPXx68i04u  1MHb9ROmrgyGvPXx68i04u
# 389  spotify:track:1jCcfSHdXosT54e64GFRE1  1jCcfSHdXosT54e64GFRE1
# 390  spotify:track:3PphHkiVdhRaO1EWH6ZWqZ  3PphHkiVdhRaO1EWH6ZWqZ
#
#                               track.name  track.popularity  danceability  \
# 0                         All I Wanna Do              74.0         0.820
# 1    Maria Maria (feat. The Product G&B)              83.0         0.777
# 2                 Dreams - 2004 Remaster              87.0         0.828
# 3                             Lovely Day              81.0         0.692
# 4                      Dog Days Are Over              79.0         0.492
# ..                                   ...               ...           ...
# 386                            Blue Hair              86.0         0.751
# 387                          Stereotypes              34.0         0.677
# 388                           Vulnerable              44.0         0.598
# 389                   Deceive Me So Easy               3.0         0.400
# 390                      Yards / Gardens              61.0         0.800
#
#      energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0     0.528    9   -11.179     1       0.0321        0.1110          0.018600
# 1     0.601    2    -5.931     1       0.1260        0.0406          0.002010
# 2     0.492    0    -9.744     1       0.0276        0.0644          0.004280
# 3     0.651    9    -8.267     1       0.0324        0.2920          0.002410
# 4     0.810    7    -5.315     1       0.0847        0.0416          0.003790
# ..      ...  ...       ...   ...          ...           ...               ...
# 386   0.720    4    -6.376     1       0.0303        0.5540          0.049700
# 387   0.475   11    -6.113     1       0.0308        0.5320          0.000000
# 388   0.183    9   -13.487     1       0.0304        0.5350          0.000062
# 389   0.457    9   -10.543     0       0.0404        0.3680          0.006790
# 390   0.544   10    -7.520     1       0.0320        0.2680          0.617000
#
#      liveness  valence    tempo  duration_ms  time_signature weather_type
# 0      0.2570   0.9310  120.091       272107               4          sun
# 1      0.0348   0.6800   97.911       261973               4          sun
# 2      0.1280   0.7890  120.151       257800               4          sun
# 3      0.1050   0.7060   97.923       254560               4          sun
# 4      0.1170   0.2450  149.954       251840               4          sun
# ..        ...      ...      ...          ...             ...          ...
# 386    0.2580   0.8840  135.730       217000               4         rain
# 387    0.2030   0.6120  117.822       168424               4         rain
# 388    0.1290   0.0796  137.035       155146               4         rain
# 389    0.3150   0.1390   77.182       238213               4         rain
# 390    0.1100   0.7450  107.984       141743               4         rain
#
# [701 rows x 18 columns]

# %%
weather_for_ML = weather_songs.iloc[:,3:].reset_index()
weather_for_ML['weather_type'] = weather_for_ML['weather_type'].map({'rain':0, 'sun':1})
weather_for_ML
# Out:
#      index  track.popularity  danceability  energy  key  loudness  mode  \
# 0        0              74.0         0.820   0.528    9   -11.179     1
# 1        1              83.0         0.777   0.601    2    -5.931     1
# 2        2              87.0         0.828   0.492    0    -9.744     1
# 3        3              81.0         0.692   0.651    9    -8.267     1
# 4        4              79.0         0.492   0.810    7    -5.315     1
# ..     ...               ...           ...     ...  ...       ...   ...
# 696    386              86.0         0.751   0.720    4    -6.376     1
# 697    387              34.0         0.677   0.475   11    -6.113     1
# 698    388              44.0         0.598   0.183    9   -13.487     1
# 699    389               3.0         0.400   0.457    9   -10.543     0
# 700    390              61.0         0.800   0.544   10    -7.520     1
#
#      speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0         0.0321        0.1110          0.018600    0.2570   0.9310  120.091
# 1         0.1260        0.0406          0.002010    0.0348   0.6800   97.911
# 2         0.0276        0.0644          0.004280    0.1280   0.7890  120.151
# 3         0.0324        0.2920          0.002410    0.1050   0.7060   97.923
# 4         0.0847        0.0416          0.003790    0.1170   0.2450  149.954
# ..           ...           ...               ...       ...      ...      ...
# 696       0.0303        0.5540          0.049700    0.2580   0.8840  135.730
# 697       0.0308        0.5320          0.000000    0.2030   0.6120  117.822
# 698       0.0304        0.5350          0.000062    0.1290   0.0796  137.035
# 699       0.0404        0.3680          0.006790    0.3150   0.1390   77.182
# 700       0.0320        0.2680          0.617000    0.1100   0.7450  107.984
#
#      duration_ms  time_signature  weather_type
# 0         272107               4             1
# 1         261973               4             1
# 2         257800               4             1
# 3         254560               4             1
# 4         251840               4             1
# ..           ...             ...           ...
# 696       217000               4             0
# 697       168424               4             0
# 698       155146               4             0
# 699       238213               4             0
# 700       141743               4             0
#
# [701 rows x 16 columns]

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(weather_for_ML, test_size=0.2, random_state=42)

test_set, validation_set = train_test_split(test_set, test_size = 0.5, random_state=42)

X_train = train_set.drop("weather_type", axis=1)
y_train = train_set["weather_type"].copy()

X_test = test_set.drop("weather_type", axis=1)
y_test = test_set["weather_type"].copy()

X_validation = validation_set.drop("weather_type", axis=1)
y_validation = validation_set["weather_type"].copy()

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (560, 15)
# (70, 15)
# (560,)
# (70,)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeRegressor

tree_reg = DecisionTreeRegressor(random_state=42)
tree_reg.fit(X_train, y_train)
y_predict_DT = tree_reg.predict(X_test)
tree_mse = mean_squared_error(y_test, y_predict_DT)
tree_rmse = np.sqrt(tree_mse)
tree_rmse
# Out:
# 0.4140393356054125

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_predict_DT, y_test)
# Out:
# array([[30,  7],
#        [ 5, 28]])

# %%
from sklearn.metrics import classification_report
 
print(classification_report(y_test, y_predict_DT))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.86      0.83        35
#            1       0.85      0.80      0.82        35
#
#     accuracy                           0.83        70
#    macro avg       0.83      0.83      0.83        70
# weighted avg       0.83      0.83      0.83        70
